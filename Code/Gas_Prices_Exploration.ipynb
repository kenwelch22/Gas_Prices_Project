# %%
import json
import requests
from config import api_key
import datetime

# %%
from pprint import pprint

# %%
# weekly gas prices from 2000 to 2020
url = 'http://api.eia.gov/series/?api_key=YOUR_API_KEY_HERE&series_id=PET.EMM_EPM0_PTE_SCA_DPG.W'
url_new = url.replace('YOUR_API_KEY_HERE', api_key)

# %%
api_response = requests.get(url_new)
api_json = api_response.json()

# %%
pprint(api_json)
# Out:
# {'request': {'command': 'series', 'series_id': 'PET.EMM_EPM0_PTE_SCA_DPG.W'},
#  'series': [{'copyright': 'None',
#              'data': [['20200323', 3.142],
#                       ['20200316', 3.298],
#                       ['20200309', 3.403],
#                       ['20200302', 3.435],
#                       ['20200224', 3.443],
#                       ['20200217', 3.441],
#                       ['20200210', 3.449],
#                       ['20200203', 3.455],
#                       ['20200127', 3.467],
#                       ['20200120', 3.487],
#                       ['20200113', 3.497],
#                       ['20200106', 3.505],
#                       ['20191230', 3.517],
#                       ['20191223', 3.536],
#                       ['20191216', 3.588],
#                       ['20191209', 3.657],
#                       ['20191202', 3.75],
#                       ['20191125', 3.825],
#                       ['20191118', 3.918],
# ...

# %%
pprint(api_json['series'])
# Out:
# [{'copyright': 'None',
#   'data': [['20200323', 3.142],
#            ['20200316', 3.298],
#            ['20200309', 3.403],
#            ['20200302', 3.435],
#            ['20200224', 3.443],
#            ['20200217', 3.441],
#            ['20200210', 3.449],
#            ['20200203', 3.455],
#            ['20200127', 3.467],
#            ['20200120', 3.487],
#            ['20200113', 3.497],
#            ['20200106', 3.505],
#            ['20191230', 3.517],
#            ['20191223', 3.536],
#            ['20191216', 3.588],
#            ['20191209', 3.657],
#            ['20191202', 3.75],
#            ['20191125', 3.825],
#            ['20191118', 3.918],
#            ['20191111', 3.999],
#            ['20191104', 4.035],
#            ['20191028', 4.021],
#            ['20191021', 4.106],
#            ['20191014', 4.166],
#            ['20191007', 4.169],
#            ['20190930', 4.034],
#            ['20190923', 3.689],
#            ['20190916', 3.571],
# ...

# %%
api_json_series = api_json['series']
api_json_series = api_json_series[0]

# %%
api_json_data = api_json_series['data']
#api_json_data = api_json_data[0]

# %%
data = []
for i in api_json_data:
    data.append(i)

# %%
test = data[150][0]

# %%
ident = 0
for i in api_json_data:
    decoded_data['id'] = ident
    deconed_data['id'][ident] =  
    ident += 1
# Out:
#   File "<ipython-input-74-c0568572966d>", line 3
#     }
#     ^
# SyntaxError: invalid syntax

# %%
test
# Out:
# '20170508'

# %%
datetimetest = datetime.datetime.strptime(test, '%Y%d%m')

# %%
test1 = datetimetest.date().year
test2 = datetimetest.date().day
test3 = datetimetest.date().month

# %%
test1
# Out:
# 2017

# %%
test2
# Out:
# 5

# %%
test3
# Out:
# 8

# %%
print (f')
# Out:
#   File "<ipython-input-111-dd90ee2d4216>", line 3
#     ''')
#
# ^
# SyntaxError: invalid syntax
